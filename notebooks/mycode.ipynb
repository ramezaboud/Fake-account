# %%
import feature_engineer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
real = pd.read_csv('users.csv')
fake = pd.read_csv('fusers.csv')
df_all = pd.concat([real, fake], ignore_index=True, sort=False)
y = np.array([1]*len(real) + [0]*len(fake))

# %%
X_train, X_test, y_train, y_test = train_test_split(df_all, y, test_size=0.4, random_state=44, stratify=y)
code
python
# Inspect module attributes (show names and repr) to find any similarly-named identifiers
import importlib.util, pprint
path = r'd:\project python\ml project 2\feature_engineer.py'
spec = importlib.util.spec_from_file_location('fe_debug2', path)
mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)
names = sorted(mod.__dict__.keys())
# print any name that contains letters from 'Feature' or 'Engineer' or close length
candidates = [n for n in names if 'Feature' in n or 'Engineer' in n or 'Featur' in n or 'Engine' in n]
print('candidates (direct substring):', candidates)
# print repr of all names to spot hidden characters
for n in names:
    if any(ch in n for ch in ['Feature','Engineer','Featur','Engine']):
        print('name repr:', repr(n))
# Also show first 200 names to inspect unexpected identifiers
print('--- all names (first 200) ---')
pprint.pprint(names[:200])

# %%
pipeline = Pipeline([
    ('feature_engineer', FeatureEngineer()),
    ('scaler', StandardScaler()),   # optional for RF
    ('clf', RandomForestClassifier(random_state=42))
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 pipeline = Pipeline([
# ----> 2     ('feature_engineer', FeatureEngineer()),
#       3     ('scaler', StandardScaler()),   # optional for RF
#       4     ('clf', RandomForestClassifier(random_state=42))
#       5 ])
#
# TypeError: 'module' object is not callable

# %%
real = pd.read_csv('users.csv')
Fake = pd.read_csv('fusers.csv')
df = pd.concat([real, Fake], ignore_index=True, sort=False)
y = np.array([1]*len(real) + [0]*len(Fake))

# %%
df.columns
# Out:
# Index(['id', 'name', 'screen_name', 'statuses_count', 'followers_count',
#        'friends_count', 'favourites_count', 'listed_count', 'created_at',
#        'url', 'lang', 'time_zone', 'location', 'default_profile',
#        'default_profile_image', 'geo_enabled', 'profile_image_url',
#        'profile_banner_url', 'profile_use_background_image',
#        'profile_background_image_url_https', 'profile_text_color',
#        'profile_image_url_https', 'profile_sidebar_border_color',
#        'profile_background_tile', 'profile_sidebar_fill_color',
#        'profile_background_image_url', 'profile_background_color',
#        'profile_link_color', 'utc_offset', 'protected', 'verified',
#        'description', 'updated', 'dataset'],
#       dtype='object')

# %%
cols_to_drop = [
    'id', 'screen_name', 'url', 'time_zone', 'location',
    'profile_image_url', 'profile_image_url_https', 'profile_banner_url',
    'profile_background_image_url_https', 'profile_background_image_url',
    'profile_background_color', 'profile_text_color', 'profile_sidebar_border_color',
    'profile_sidebar_fill_color', 'profile_background_tile', 'profile_link_color',
    'profile_use_background_image', 'updated', 'dataset', 'geo_enabled', 'utc_offset'
]

df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

df.columns
# Out:
# Index(['name', 'statuses_count', 'followers_count', 'friends_count',
#        'favourites_count', 'listed_count', 'created_at', 'lang',
#        'default_profile', 'default_profile_image', 'protected', 'verified',
#        'description'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name                        0
# statuses_count              0
# followers_count             0
# friends_count               0
# favourites_count            0
# listed_count                0
# created_at                  0
# lang                        0
# default_profile          1090
# default_profile_image    2810
# protected                2818
# verified                 2818
# description               271
# dtype: int64
